# %%
import pandas as pd
import numpy as np
import sklearn as sk
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_moons

# %%
x , y = make_moons(n_samples = 100, noise = 0.25, random_state = 3)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify = y, random_state = 42)

# %%
import matplotlib.pyplot as plt
mlp = MLPClassifier(solver = 'lbfgs', random_state = 0).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60)
plt.grid('on')
plt.show()

# %%
mlp = MLPClassifier(solver = 'lbfgs', random_state = 0, hidden_layer_sizes = [10]).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60)
plt.grid('on')
plt.show()

# %%
import matplotlib.cm as cm
plt.cm.register_cmap(name = 'swirly', cmap = y_train)
plt.imshow(x_train, cmap = cm.hot)
plt.show()

# %%
plt.set_cmap(cm.hot)

# %%
plt.set_cmap(cm.jet)
mlp = MLPClassifier(solver = 'lbfgs', random_state = 0, hidden_layer_sizes = [10]).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60, cmap = cm.jet)
plt.grid('on')
plt.show()

# %%
plt.set_cmap(cm.jet)
mlp = MLPClassifier(solver = 'lbfgs', random_state = 0, hidden_layer_sizes = [10]).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60)
plt.grid('on')
plt.show()

# %%
# using two hidden layers, with 10 units each
mlp = MLPClassifier(solver = 'lbfgs', random_state = 0, hidden_layer_sizes = [10,10]).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60, cmap = cm.jet)
plt.grid('on')
plt.show()

# %%
# using two hidden layers, with 10 units each, now with tanh nonlinearity

mlp = MLPClassifier(solver = 'lbfgs', activation = 'tanh', random_state = 0, hidden_layer_sizes = [10,10]).fit(x_train, y_train)
plt.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60, cmap = cm.jet)
plt.grid('on')
plt.show()

# %%
fig, axes = plt.subplots(2,4, figsize = (20,8))
for ax, n_hidden_nodes in zip(axes, [10,100]):
    for axx, alpha in zip(ax, [0.001, 0.01, 0.1,1]):
        mlp = MLPClassifier(solver = 'lbfgs', activation = 'relu', random_state = 0,
                           hidden_layer_sizes = [n_hidden_nodes, n_hidden_nodes],
                           alpha = alpha)
        mlp.fit(x_train, y_train)
        axx.scatter(x_train[:,0], x_train[:,1], c = y_train, s = 60, cmap = cm.jet)
        axx.set_title('n_hidden = [%d, %d]\alpha = %.4f'%(n_hidden_nodes, n_hidden_nodes, alpha))
plt.show()
